# %%
# https://www.jaided.ai/easyocr/documentation/

# %%
pip install easyocr

# %%
import easyocr

reader = easyocr.Reader(['pt'])

result = reader.readtext(
    image='/home/flaviogaspareto/documents/vscode/knowledge_base/images/image.png',
    paragraph=True
    )

result
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 5
#       1 import easyocr
#       3 reader = easyocr.Reader(['pt'])
# ----> 5 result = reader.readtext(
#       6     image='/home/flaviogaspareto/documents/vscode/knowledge_base/images/image.png',
#       7     paragraph=True
#       8     )
#      10 result
#
# ...
